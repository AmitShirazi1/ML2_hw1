# %% [markdown]
# # <u>Submission instructions</u>
# ### Submission in pairs unless otherwise authorized
# <ul style="font-size: 17px">
# <li> This notebook contains all the questions. You should follow the instructions below.</li>
# <li> Solutions for both theoretical and practical parts should be written in this notebook</li>
# </ul>
#
# <h3> Moodle submission</h3>
#
#
# <p style="font-size: 17px">
# You should submit three files:
# </p>
# <ul style="font-size: 17px">
# <li>IPYNB notebook:
#   <ul>
#   <li>All the wet and dry parts, including code, graphs, discussion, etc.</li>
#   </ul>
# </li>
# <li>PDF file:
#   <ul>
#   <li>Export the notebook to PDF. Make sure that all the cells are visible.</li>
#   </ul>
# </li>
# <li>Pickle files:
#   <ul>
#     <li>As requested in Q2.a and Q3.a</li>
#   </ul>
# </li>
# <li> PY file:
#   <ul>
#    <li> As requested in Q3.a</li>
#    </ul>
#    </li>
# </ul>
# <p style="font-size: 17px">
# All files should be in the following format: "HW1_ID1_ID2.file"
# <br>
# Good Luck!
# </p>

# %% [markdown]
# <h1> Question 1</h1>

# %% [markdown]
# ## I. Softmax Derivative (10pt)
#
# <p style="font-size: 17px">
# Derive the gradients of the softmax function and demonstrate how the expression can be reformulated solely by using the softmax function, i.e., in some expression where only $softmax(x)$, but not $x$, is present). Recall that the softmax function is defined as follows:
#
# $$softmax(x)_i = \frac{e^{x_i}}{\sum_{j=1}^{N} e^{x_j}}$$

# %% [markdown]
# ### I. Softmax Derivative - Answer:
# $$ \frac{\partial softmax(x)_i}{\partial x_k} = \frac{\partial }{\partial x_k} (\frac{e^{x_i}}{\sum_{j=1}^{N} e^{x_j}})= $$
# $$ = (\frac{\partial }{\partial x_k} e^{x_i}) \cdot \frac{1}{\sum_{j=1}^{N} e^{x_j}} + e^{x_i}(\frac{\partial }{\partial x_k} \frac{1}{\sum_{j=1}^{N} e^{x_j}})= $$
# $$ = \frac{e^{x_k}}{\sum_{j=1}^{N} e^{x_j}} \cdot I_{i=k} - \frac{e^{x_i}e^{x_k}}{(\sum_{j=1}^{N} e^{x_j})^2}= $$
# $$ = \frac{e^{x_k}}{\sum_{j=1}^{N} e^{x_j}} \cdot I_{i=k} - \frac{e^{x_i}}{\sum_{j=1}^{N} e^{x_j}} \cdot \frac{e^{x_k}}{\sum_{j=1}^{N} e^{x_j}}= $$
# $$ = softmax(x)_k \cdot I_{i=k} - softmax(x)_i \cdot softmax(x)_k= $$
# $$ = softmax(x)_k (I_{i=k} - softmax(x)_i) $$

# %% [markdown]
# ## II. Cross-Entropy Gradient (10pt)
# <p style="font-size: 17px">
# Derive the gradient of cross-entropy loss with regard to the inputs of a softmax function. i.e., find the gradients with respect to the softmax input vector $\theta$, when the prediction is denoted by $\hat{y} = softmax(\theta)$. Remember the cross entropy function is:
# $$CE(y, \hat{y}) = -\sum_i y_i log(\hat{y_i})$$
#
#
# <p style="font-size: 17px">where $y$ is the one-hot label vector, and $\hat{y}$ is the predicted probability vector for all classes.

# %% [markdown]
# ### II. Cross-Entropy Gradient - Answer
#
# <!--- write your answer -->
# $$\frac{\partial CE(y, \hat{y})}{\partial\theta} = ( \frac{\partial CE(y, \hat{y})}{\partial\theta _1} , \frac{\partial CE(y, \hat{y})}{\partial\theta _2} , ... , \frac{\partial CE(y, \hat{y})}{\partial\theta _N} ) $$
# $$ \Downarrow $$
# $$ \frac{\partial CE(y, \hat{y})}{\partial\theta _k} = \frac{\partial CE(y, \hat{y})}{\partial \hat{y}} \cdot \frac{\partial \hat{y}}{\partial\theta _k} = $$
# $$ \sum_{i=1}^{N} \frac{\partial CE(y, \hat{y})}{\partial \hat{y}_i} \cdot \frac{\partial \hat{y}_i}{\partial\theta _k} = $$
# $$ \sum_{i=1}^{N} (- \frac{y_i}{\hat{y}_i} \cdot \hat{y}_k (I_{i=k} - \hat{y}_i) ) = $$
# $$ \sum_{i=1}^{N} (- y_i I_{i=k} + y_i \hat{y}_k ) = $$
# $$ - y_k + (\sum_{i=1}^{N} y_i) \hat{y}_k = $$
# $$ - y_k + 1 \cdot \hat{y}_k = \hat{y}_k - y_k $$
# $$ \Downarrow $$
# $$\frac{\partial CE(y, \hat{y})}{\partial\theta} = ( \hat{y}_1 - y_1 , \hat{y}_2 - y_2 , ... , \hat{y}_N - y_N ) = \hat{y} - y $$

# %% [markdown]
# # Colab nessecities

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mon Dec 16 10:25:28 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0              43W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !unzip /content/sample_data/hw1_data.zip -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0649.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0649.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0113.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0113.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0675.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0675.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0661.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0661.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0107.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0107.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0488.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0488.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0339.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0339.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0477.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0477.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0311.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0311.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0305.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0305.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0463.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0463.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0259.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0259.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0503.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0503.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0265.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0265.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0271.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0271.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0517.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0517.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0098.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0098.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0067.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0067.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0073.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0073.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0072.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0072.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0066.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0066.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0700.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0700.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0099.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0099.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0270.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0270.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0516.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0516.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0502.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0502.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0264.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0264.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0258.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0258.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0304.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0304.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0462.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0462.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0476.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0476.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0310.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0310.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0338.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0338.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0489.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0489.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0660.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0660.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0106.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0106.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0112.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0112.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0674.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0674.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0648.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0648.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0689.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0689.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0138.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0138.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0104.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0104.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0662.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0662.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0676.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0676.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0110.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0110.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0448.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0448.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0460.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0460.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0306.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0306.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0312.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0312.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0474.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0474.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0299.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0299.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0528.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0528.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0514.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0514.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0272.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0272.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0266.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0266.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0500.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0500.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0058.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0058.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0070.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0070.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0064.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0064.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0065.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0065.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0071.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0071.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0059.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0059.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0267.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0267.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0501.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0501.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0515.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0515.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0273.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0273.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0529.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0529.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0298.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0298.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0313.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0313.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0475.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0475.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0461.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0461.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0307.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0307.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0449.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0449.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0677.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0677.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0111.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0111.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0105.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0105.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0663.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0663.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0139.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0139.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0688.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0688.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0698.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0698.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0667.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0667.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0101.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0101.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0115.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0115.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0673.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0673.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0129.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0129.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0303.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0303.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0465.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0465.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0471.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0471.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0317.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0317.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0459.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0459.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0288.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0288.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0277.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0277.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0511.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0511.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0505.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0505.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0263.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0263.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0539.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0539.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0075.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0075.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0061.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0061.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0049.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0049.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0048.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0048.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0060.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0060.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0074.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0074.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0538.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0538.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0504.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0504.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0262.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0262.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0276.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0276.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0510.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0510.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0289.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0289.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0458.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0458.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0470.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0470.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0316.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0316.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0302.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0302.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0464.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0464.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0128.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0128.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0114.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0114.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0672.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0672.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0666.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0666.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0100.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0100.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0699.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0699.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0670.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0670.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0116.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0116.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0102.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0102.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0664.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0664.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0658.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0658.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0499.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0499.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0314.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0314.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0472.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0472.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0466.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0466.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0300.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0300.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0328.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0328.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0260.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0260.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0506.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0506.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0512.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0512.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0274.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0274.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0248.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0248.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0089.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0089.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0062.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0062.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0076.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0076.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0077.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0077.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0063.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0063.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0088.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0088.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0249.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0249.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0513.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0513.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0275.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0275.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0261.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0261.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0507.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0507.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0329.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0329.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0467.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0467.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0301.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0301.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0315.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0315.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0473.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0473.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0498.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0498.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0659.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0659.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0103.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0103.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0665.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0665.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0671.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0671.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0117.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0117.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0158.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0158.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0616.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0616.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0170.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0170.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0164.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0164.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0602.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0602.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0399.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0399.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0428.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0428.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0372.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0372.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0414.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0414.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0400.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0400.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0366.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0366.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0548.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0548.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0206.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0206.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0560.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0560.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0574.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0574.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0212.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0212.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0038.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0038.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0004.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0004.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0010.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0010.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0011.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0011.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0005.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0005.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0039.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0039.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0575.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0575.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0213.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0213.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0207.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0207.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0561.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0561.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0549.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0549.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0401.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0401.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0367.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0367.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0373.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0373.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0415.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0415.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0429.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0429.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0398.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0398.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0165.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0165.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0603.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0603.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0617.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0617.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0171.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0171.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0159.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0159.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0198.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0198.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0629.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0629.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0601.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0601.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0167.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0167.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0173.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0173.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0615.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0615.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0359.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0359.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0365.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0365.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0403.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0403.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0417.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0417.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0371.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0371.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0588.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0588.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0239.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0239.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0211.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0211.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0577.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0577.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0563.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0563.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0205.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0205.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0013.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0013.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0007.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0007.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0006.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0006.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0012.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0012.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0562.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0562.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0204.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0204.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0210.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0210.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0576.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0576.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0238.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0238.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0589.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0589.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0416.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0416.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0370.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0370.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0364.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0364.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0402.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0402.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0358.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0358.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0172.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0172.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0614.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0614.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0600.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0600.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0166.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0166.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0628.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0628.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0199.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0199.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0189.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0189.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0162.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0162.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0604.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0604.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0610.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0610.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0176.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0176.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0638.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0638.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0406.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0406.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0360.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0360.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0374.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0374.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0412.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0412.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0348.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0348.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0599.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0599.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0572.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0572.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0214.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0214.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0200.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0200.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0566.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0566.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0228.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0228.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0016.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0016.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0002.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0002.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0003.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0003.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0017.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0017.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0229.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0229.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0201.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0201.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0567.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0567.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0573.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0573.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0215.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0215.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0598.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0598.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0349.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0349.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0375.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0375.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0413.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0413.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0407.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0407.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0361.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0361.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0639.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0639.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0611.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0611.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0177.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0177.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0163.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0163.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0605.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0605.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0188.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0188.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0175.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0175.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0613.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0613.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0607.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0607.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0161.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0161.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0149.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0149.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0388.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0388.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0411.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0411.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0377.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0377.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0363.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0363.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0405.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0405.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0439.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0439.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0565.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0565.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0203.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0203.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0217.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0217.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0571.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0571.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0559.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0559.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0001.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0001.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0015.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0015.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0029.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0029.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0028.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0028.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0014.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0014.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0558.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0558.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0216.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0216.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0570.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0570.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0564.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0564.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0202.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0202.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0438.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0438.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0362.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0362.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0404.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0404.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0410.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0410.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0376.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0376.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0389.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0389.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0148.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0148.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0606.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0606.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0160.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0160.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0174.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0174.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0612.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0612.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0192.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0192.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0186.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0186.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0179.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0179.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0637.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0637.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0151.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0151.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0145.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0145.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0623.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0623.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0390.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0390.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0384.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0384.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0409.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0409.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0353.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0353.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0435.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0435.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0421.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0421.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0347.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0347.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0582.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0582.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0596.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0596.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0569.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0569.jpg
#   inflating: /content/hw1_data/Dog_Emotion/train/sad/sad_0227.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/train/sad/._sad_0227.jpg
# ...
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/angry/._angry_0737.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0789.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0789.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0762.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0762.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0776.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0776.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0777.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0777.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0763.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0763.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0788.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0788.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0749.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0749.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0775.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0775.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0761.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0761.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0760.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0760.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0774.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0774.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0748.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0748.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0770.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0770.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0764.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0764.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0758.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0758.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0759.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0759.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0765.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0765.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0771.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0771.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0798.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0798.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0767.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0767.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0773.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0773.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0772.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0772.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0766.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0766.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0799.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0799.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0729.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0729.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0701.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0701.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0715.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0715.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0714.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0714.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0728.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0728.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0716.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0716.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0702.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0702.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0703.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0703.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0717.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0717.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0713.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0713.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0707.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0707.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0706.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0706.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0712.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0712.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0704.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0704.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0710.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0710.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0738.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0738.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0739.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0739.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0711.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0711.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0705.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0705.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0708.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0708.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0720.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0720.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0734.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0734.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0735.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0735.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0721.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0721.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0709.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0709.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0737.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0737.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0723.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0723.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0722.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0722.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0736.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0736.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0732.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0732.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0726.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0726.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0727.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0727.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0733.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0733.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0725.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0725.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0731.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0731.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0719.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0719.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0718.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0718.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0730.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0730.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0724.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0724.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0780.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0780.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0794.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0794.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0743.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0743.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0757.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0757.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0756.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0756.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0742.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0742.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0795.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0795.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0781.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0781.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0797.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0797.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0783.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0783.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0768.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0768.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0754.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0754.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0740.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0740.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0741.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0741.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0755.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0755.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0769.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0769.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0782.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0782.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0796.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0796.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0792.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0792.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0786.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0786.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0751.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0751.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0745.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0745.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0779.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0779.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0778.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0778.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0744.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0744.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0750.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0750.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0787.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0787.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0793.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0793.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0785.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0785.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0791.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0791.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0746.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0746.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0752.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0752.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0800.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0800.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0753.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0753.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0747.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0747.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0790.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0790.jpg
#   inflating: /content/hw1_data/Dog_Emotion/val/relaxed/relaxed_0784.jpg
#   inflating: /content/__MACOSX/hw1_data/Dog_Emotion/val/relaxed/._relaxed_0784.jpg

# %%
RESOURCES_DIR = '/content/hw1_data/'

# %% [markdown]
# # Question 2

# %% [markdown]
# ## I. Derivative Of Activation Functions (10pt)
#
# <p style="font-size: 17px">
# The following cell contains an implementation of some activation functions. Implement the corresponding derivatives.</p>

# %%
import torch

def sigmoid(x):
    return 1 / (1 + torch.exp(-x))

def tanh(x):
    return torch.div(torch.exp(x) - torch.exp(-x), torch.exp(x) + torch.exp(-x))


def softmax(x):
    exp_x = torch.exp(x.T - torch.max(x, dim=-1).values).T  # Subtracting max(x) for numerical stability
    return exp_x / exp_x.sum(dim=-1, keepdim=True)

# %%
def d_sigmoid(x):
    return torch.exp(-x) / (1 + torch.exp(-x))**2


def d_tanh(x):
    return 1 - tanh(x)**2


def d_softmax(x):
    s = softmax(x)
    s = s.unsqueeze(-1)  # Adds a dimension
    i_equal_k_case = torch.diag_embed(s)
    return i_equal_k_case - torch.matmul(s, s.transpose(-1, -2))

# %% [markdown]
# ## II. Train a Fully Connected network on MNIST (30pt)

# %% [markdown]
# <p style="font-size: 17px">In the following exercise, you will create a classifier for the MNIST dataset.
# You should write your own training and evaluation code and meet the following
# constraints:
# <ul>
# <li> You are only allowed to use torch tensor manipulations.</li>
# <li> You are NOT allowed to use:
#   <ul>
#   <li> Auto-differentiation - backward()</li>
#   <li> Built-in loss functions</li>
#   <li> Built-in activations</li>
#   <li> Built-in optimization</li>
#   <li> Built-in layers (torch.nn)</li>
#   </ul>
#   </li>
# </ul>
# </h4>

# %% [markdown]
# <p style="font-size: 17px">
#  a) The required classifier class is defined.
# <ul style="font-size: 17px">
# <li> You should implement the forward and backward passes of the model.
# <li> Train the model and plot the model's accuracy and loss (both on train and test sets) as a function of the epochs.
# <li> You should save the model's weights and biases. Change the student_ids to yours.
# </ul>
# <p style="font-size: 17px">In this section, you <b>must</b> use the "set_seed" function with the given seed and <b>sigmoid</b> as an activation function.
# </p>

# %%
import torch
import torchvision
from torch.utils.data import DataLoader

import os
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# Constants
SEED = 42
EPOCHS = 16
BATCH_SIZE = 32
NUM_OF_CLASSES = 10

# Setting seed
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ["PYTHONHASHSEED"] = str(seed)


# Transformation for the data
transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor(),
     torchvision.transforms.Lambda(lambda x: x.view(-1))])


# Cross-Entropy loss implementation
def one_hot(y, num_of_classes=10):
    hot = torch.zeros((y.size()[0], num_of_classes))
    hot[torch.arange(y.size()[0]), y] = 1
    return hot

def cross_entropy(y, y_hat):
    y_hat = torch.clip(y_hat, 1e-9, 1 - 1e-9)
    return -torch.sum(one_hot(y) * torch.log(y_hat)) / y.size()[0]

# %%
# Create dataloaders
train_dataset = torchvision.datasets.MNIST(root='./data', train=True,
                                            download=True, transform=transform)
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE)


test_dataset = torchvision.datasets.MNIST(root='./data', train=False,
                                           download=True, transform=transform)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE,)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.08MB/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 65.4kB/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.27MB/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.48MB/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
class FullyConnectedNetwork:
    def __init__(self, input_size, output_size, hidden_size1, activiation_func, lr=0.01):
        # parameters
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_size1 = hidden_size1

        # activation function
        self.activation_func = activiation_func

        # weights
        self.W1 = torch.randn(self.input_size, self.hidden_size1) * 0.01
        self.b1 = torch.zeros(self.hidden_size1)

        self.W2 = torch.randn(self.hidden_size1, self.output_size)
        self.b2 = torch.zeros(self.output_size)

        self.lr = lr


    def forward(self, x):
        self.z1 = torch.matmul(x, self.W1) + self.b1
        self.s1 = self.activation_func(self.z1)

        self.z2 = torch.matmul(self.s1, self.W2) + self.b2
        self.s2 = softmax(self.z2)

        return self.s2


    def backward(self, x, y, y_hat):
        # Computing gradients of the loss w.r.t. W2, b2
        y = one_hot(y, self.output_size)  # Turn the label to a one-hot vector
        n = x.shape[0]
        dL_dz2 = (y_hat - y)  # As we proved in the first question, derivative of CE with softmax is y_hat - y.
        dz2_dW2 = self.s1  # Because z2 = s1 * W2 + b2
        dL_dW2 = torch.matmul(dz2_dW2.T, dL_dz2) / n  # Chain rule: dL_dW2 = dL_dz2 * dz2_dW2. Also normalizing by batch size.
        dL_db2 = dL_dz2.sum(axis=0) / n  # Chain rule: dL_db2 = dL_dz2 * dz2_db2, normalizing by batch size.

        # Computing gradients of the loss w.r.t. W1, b1
        dz2_ds1 = self.W2
        dL_ds1 = torch.matmul(dL_dz2, dz2_ds1.T)  # Chain rule: dL_ds1 = dL_dz2 * dz2_ds1
        ds1_dz1 = d_sigmoid(self.z1)
        dL_dz1 = dL_ds1 * ds1_dz1  # Chain rule
        dz1_dW1 = x
        dL_dW1 = torch.matmul(dz1_dW1.T, dL_dz1) / n
        dL_db1 = dL_dz1.sum(axis=0) / n

        # Updating weights
        self.W2 -= self.lr * dL_dW2
        self.b2 -= self.lr * dL_db2
        self.W1 -= self.lr * dL_dW1
        self.b1 -= self.lr * dL_db1

    def train(self, train_dataloader):
        total_loss, num_correct_predictions = 0, 0
        for x, y in train_dataloader:
            x = x.view(x.size(0), -1)
            y_hat = self.forward(x)
            loss = cross_entropy(y, y_hat)
            total_loss += loss.item()
            num_correct_predictions += torch.sum(torch.argmax(y_hat, dim=-1) == y).item()

            self.backward(x, y, y_hat)
        return total_loss, num_correct_predictions

    def eval(self, test_dataloader):
        total_loss, num_correct_predictions = 0, 0
        with torch.no_grad():
            for x, y in test_dataloader:
                x = x.view(x.size(0), -1)
                y_hat = self.forward(x)
                loss = cross_entropy(y, y_hat)
                total_loss += loss.item()
                num_correct_predictions += torch.sum(torch.argmax(y_hat, dim=-1) == y).item()
        return total_loss, num_correct_predictions

# %%
set_seed(SEED)
model = FullyConnectedNetwork(784, 10, 128, sigmoid, lr=0.01)

# %%
training_loss, test_loss, training_accuracy, test_accuracy = list(), list(), list(), list()
for epoch in range(EPOCHS):
    # First stage: Training
    total_loss, num_correct_predictions = model.train(train_dataloader)
    training_loss.append(total_loss / len(train_dataloader))
    training_accuracy.append(num_correct_predictions / len(train_dataset))

    # Second stage: Testing
    total_loss, num_correct_predictions = model.eval(test_dataloader)
    test_loss.append(total_loss / len(test_dataloader))
    test_accuracy.append(num_correct_predictions / len(test_dataset))

# %%
# Plot losses
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, EPOCHS + 1), training_loss, label='Train')
plt.plot(range(1, EPOCHS + 1), test_loss, label='Test')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss as a function of epochs')
plt.legend()

# Plot accuracies
plt.subplot(1, 2, 2)
plt.plot(range(1, EPOCHS + 1), training_accuracy, label='Train')
plt.plot(range(1, EPOCHS + 1), test_accuracy, label='Test')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy as a function of epochs')
plt.legend()
plt.tight_layout()
plt.show()

# %%
students_ids = "319044434_314779166"
torch.save({"W1": model.W1, "W2": model.W2, "b1": model.b1, "b2": model.b2}, f"HW1_{students_ids}.pkl")

# %% [markdown]
# <p style="font-size: 17px"> b) Train the model with various learning rates (at least 3).
# <ul style="font-size: 17px">
# <li> Plot the model's accuracy and loss (both on train and test sets) as a function of the epochs.
# <li>Discuss the differences in training with different learning rates. Support your answer with plots.

# %%
learning_rates = [0.0001, 0.001, 0.01, 0.1, 0.5, 1]
results = {}

for lr in learning_rates:
    set_seed(SEED)
    model = FullyConnectedNetwork(784, 10, 128, sigmoid, lr=lr)

    # Train and evaluate
    training_loss, test_loss, training_accuracy, test_accuracy = list(), list(), list(), list()
    for epoch in range(EPOCHS):
        # First stage: Training
        total_loss, num_correct_predictions = model.train(train_dataloader)
        training_loss.append(total_loss / len(train_dataloader))
        training_accuracy.append(num_correct_predictions / len(train_dataset))

        # Second stage: Testing
        total_loss, num_correct_predictions = model.eval(test_dataloader)
        test_loss.append(total_loss / len(test_dataloader))
        test_accuracy.append(num_correct_predictions / len(test_dataset))

    # Store results
    results[lr] = {
        "train_loss": training_loss,
        "test_loss": test_loss,
        "train_acc": training_accuracy,
        "test_acc": test_accuracy
    }

# Plot results
plt.figure(figsize=(16, 12))

for idx, lr in enumerate(learning_rates):
    # Training loss
    plt.subplot(3, 2, 1)
    plt.plot(range(1, EPOCHS + 1), results[lr]["train_loss"], label=f"LR={lr}")
    plt.title("Training Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()

    # Training accuracy
    plt.subplot(3, 2, 2)
    plt.plot(range(1, EPOCHS + 1), results[lr]["train_acc"], label=f"LR={lr}")
    plt.title("Training Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()

    # Testing loss
    plt.subplot(3, 2, 3)
    plt.plot(range(1, EPOCHS + 1), results[lr]["test_loss"], label=f"LR={lr}")
    plt.title("Test Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()

    # Testing accuracy
    plt.subplot(3, 2, 4)
    plt.plot(range(1, EPOCHS + 1), results[lr]["test_acc"], label=f"LR={lr}")
    plt.title("Test Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# The learning rates affect the convergence:
# - A higher lr will descend faster and be able to escape local min. However, it may have hasteful "jumps" and might move back and forth without finding the optimum (divergence).
# - A lower lr will descend slowly and steadily. However, it might get stuck in a local minima. Also, the number of epochs required for convergence is greater.
# - Our go-to lr is somewhere in between, 0.01, because it has some stability yet it doesn't take too long to converge, in our opinion.
#
# The graphs above support these claims.
# - We can see that a low lr, 0.0001, takes a lot of epochs to achive high accuracy and a small loss.
# - As the lr increases, we're achieving better accuracy and loss in less epochs.
# - However, looking at the 2 highest lrs, 0.5 and 1, we can see a clear over-fitting: at train time, lr=1 has the same accuracy and loss levels as lr=0.5 and lr=0.01, but on test time it has inferior results to them both.

# %% [markdown]
# # Question 3

# %% [markdown]
# ## I. Implement and Train a CNN (30pt)

# %% [markdown]
# <p style="font-size: 17px"> As you might know, there are many dogs on campus. Sometimes, understanding the emotions of a dog can be challenging, and people might mistakenly try to pet it when it is sad or angry. As a data scientist, you have been asked to assist Technion's students. Your task is to create a "dog emotion classifier.
# <br>
# Your code should meet the following constraints:
# <ul style="font-size: 17px">
# <li> Your classifier must be CNN based</li>
# <li> You are not allowed to use any pre-trained model</li>
# </ul>
# <br>
# <p style="font-size: 17px">
# To satisfy your boss, your model must achieve at least 70% accuracy on the test set. Your boss also emphasized that the model will be deployed on smartphones, so it should have a small number of parameters. 25% of your grade for this task will be based on the number of parameters your model uses — fewer parameters will yield a higher grade.</p>

# %% [markdown]
# #### Stages
# <ol style="font-size: 17px">
# <li>Perform a short EDA (Exploratory Data Analysis).</li>
#  <li>Train the model and plot its accuracy and loss (for both the training and validation sets) as a function of the epochs.</li>
#   <li>Report the test set accuracy.</li>
#    <li>Discuss the progress you made and describe your final model.</li>
#     </ol>
# <br>
#  Your data is in <code>hw1_data/dog_emotion</code>.
# <br>
# You can define a custom dataset (as in tutorial 3) or use <code>torchvision.datasets.ImageFolder</code>.
#
#  #### Submission
#  <p style="font-size: 17px"> In addition to the code in the notebook, you should submit:
# <ul style="font-size: 17px">
# <li> a <code>.py</code> file containing your model class.</li>
# <li> a <code>.pkl</code> file containing the weight of your model</li>
# </ul>

# %%
import os
import matplotlib.pyplot as plt
from torchvision.datasets import ImageFolder
from torchvision import transforms
from collections import Counter
from PIL import Image
import numpy as np

# Paths to dataset
DATA_DIR = os.path.join(RESOURCES_DIR, "Dog_Emotion/")

# Transformation for loading images
transform = transforms.Compose([
    transforms.ToTensor()
])

# Load datasets
train_dataset = ImageFolder(root=os.path.join(DATA_DIR, "train/"), transform=transform)
val_dataset = ImageFolder(root=os.path.join(DATA_DIR, "val/"), transform=transform)
test_dataset = ImageFolder(root=os.path.join(DATA_DIR, "test/"), transform=transform)

# Function to count images in each class
def count_images(dataset):
    counter = Counter([label for _, label in dataset])
    return {train_dataset.classes[label]: count for label, count in counter.items()}

# Count images in each split
train_counts = count_images(train_dataset)
val_counts = count_images(val_dataset)
test_counts = count_images(test_dataset)

# Print class distributions
print("Class distribution in Train:", train_counts)
print("Class distribution in Validation:", val_counts)
print("Class distribution in Test:", test_counts)

# Combined plot for class distributions
def plot_combined_class_distribution(train_counts, val_counts, test_counts):
    classes = list(train_counts.keys())
    x = np.arange(len(classes))
    width = 0.25

    train_values = [train_counts[cls] for cls in classes]
    val_values = [val_counts[cls] for cls in classes]
    test_values = [test_counts[cls] for cls in classes]

    plt.figure(figsize=(10, 6))
    plt.bar(x - width, train_values, width, label='Train', color='skyblue')
    plt.bar(x, val_values, width, label='Validation', color='lightgreen')
    plt.bar(x + width, test_values, width, label='Test', color='salmon')

    plt.title("Class Distribution Across Splits")
    plt.xlabel("Classes")
    plt.ylabel("Number of Images")
    plt.xticks(x, classes)
    plt.legend()
    plt.show()

plot_combined_class_distribution(train_counts, val_counts, test_counts)

# Inspect one example image per class
def inspect_example_images(dataset):
    print("Example images from each class:")
    fig, axs = plt.subplots(1, len(dataset.classes), figsize=(15, 5))

    for cls_idx, cls_name in enumerate(dataset.classes):
        for img_path, label in dataset.imgs:
            if label == cls_idx:
                img = Image.open(img_path)
                axs[cls_idx].imshow(img)
                axs[cls_idx].set_title(f"Class: {cls_name}")
                axs[cls_idx].axis('off')
                break

    plt.tight_layout()
    plt.show()

inspect_example_images(train_dataset)

# Check for corrupted images
def check_corrupted_images(dataset, set_name):
    corrupted = []
    for i, (path, _) in enumerate(dataset.imgs):
        try:
            img = Image.open(path)
            img.verify()  # Verify if the image is not corrupted
        except (IOError, SyntaxError) as e:
            corrupted.append(path)
    if corrupted:
        print(f"{set_name} set: corrupted images are {corrupted}")
    else:
        print(f"{set_name} set: No corrupted images found.")

check_corrupted_images(train_dataset, "Train")
check_corrupted_images(val_dataset, "Validation")
check_corrupted_images(test_dataset, "Test")

# Optional: Analyze pixel intensity distributions
def analyze_pixel_intensity(dataset, num_samples=100):
    print("Analyzing pixel intensity distributions...")
    intensities = []
    for i in range(min(num_samples, len(dataset))):
        img, _ = dataset[i]
        intensities.append(img.numpy().flatten())
    intensities = np.concatenate(intensities)

    plt.figure(figsize=(8, 5))
    plt.hist(intensities, bins=20, color='orange', alpha=0.7)
    plt.title("Pixel Intensity Distribution")
    plt.xlabel("Normalized Pixel Value (0-black, 1-white)")
    plt.ylabel("Frequency (amount of pixels with this intensity of color)")
    plt.show()

analyze_pixel_intensity(train_dataset)
# Out:
# Class distribution in Train: {'angry': 700, 'happy': 700, 'relaxed': 700, 'sad': 700}
# Class distribution in Validation: {'angry': 100, 'happy': 100, 'relaxed': 100, 'sad': 100}
# Class distribution in Test: {'angry': 200, 'happy': 200, 'relaxed': 200, 'sad': 200}
# Example images from each class:
# Train set: No corrupted images found.
# Validation set: No corrupted images found.
# Test set: No corrupted images found.
# Analyzing pixel intensity distributions...

# %%
import torchvision.datasets as dsets
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageEnhance, ImageFilter
import torchvision.transforms.functional as F
import random

# %%
def augment_dataset(input_dir, output_dir):
    """
    Augment the entire dataset by applying additional augmentations like cropping, scaling,
    brightness adjustments, and Gaussian blur.

    Args:
    - input_dir (str): Path to the original dataset directory.
    - output_dir (str): Path to save the augmented dataset.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for label in os.listdir(input_dir):
        input_label_dir = os.path.join(input_dir, label)
        output_label_dir = os.path.join(output_dir, label)
        os.makedirs(output_label_dir, exist_ok=True)

        for img_name in os.listdir(input_label_dir):
            if img_name.endswith(('.jpg', '.jpeg', '.png')):  # Ensure valid image files
                img_path = os.path.join(input_label_dir, img_name)
                img = Image.open(img_path).convert("RGB")

                # Apply augmentations
                apply_additional_augmentations(img, output_label_dir, img_name)


def apply_additional_augmentations(image, output_label_dir, base_name):
    """
    Apply additional augmentations such as brightness, contrast, random cropping, and blurring.

    Args:
    - image (PIL.Image.Image): Input image to augment.
    - output_label_dir (str): Directory to save augmented images.
    - base_name (str): Base name of the original image.
    """
    # Save the original image
    image.save(os.path.join(output_label_dir, f"{base_name.split('.')[0]}_original.jpg"))

    # Random cropping
    for i in range(2):  # Create two cropped versions
        cropped_img = F.resized_crop(
            image,
            top=random.randint(0, 10),  # Random crop positions
            left=random.randint(0, 10),
            height=image.height - 10,
            width=image.width - 10,
            size=(image.height, image.width)
        )
        cropped_img.save(os.path.join(output_label_dir, f"{base_name.split('.')[0]}_crop{i}.jpg"))

    # Brightness/contrast adjustments
    for i in range(2):  # Create two brightness/contrast adjusted versions
        enhancer = ImageEnhance.Brightness(image)
        brightness_adjusted = enhancer.enhance(random.uniform(0.7, 1.3))  # Random brightness adjustment
        brightness_adjusted.save(os.path.join(output_label_dir, f"{base_name.split('.')[0]}_bright{i}.jpg"))

        enhancer = ImageEnhance.Contrast(image)
        contrast_adjusted = enhancer.enhance(random.uniform(0.7, 1.3))  # Random contrast adjustment
        contrast_adjusted.save(os.path.join(output_label_dir, f"{base_name.split('.')[0]}_contrast{i}.jpg"))

    # Gaussian blur
    blurred_img = image.filter(ImageFilter.GaussianBlur(radius=random.uniform(0.5, 2.0)))
    blurred_img.save(os.path.join(output_label_dir, f"{base_name.split('.')[0]}_blur.jpg"))

    # Scaling
    for i in range(2):  # Create two scaled versions
        scale_factor = random.uniform(0.8, 1.2)
        scaled_img = F.resize(image, [int(image.height * scale_factor), int(image.width * scale_factor)])
        scaled_img.save(os.path.join(output_label_dir, f"{base_name.split('.')[0]}_scale{i}.jpg"))

# Paths for offline augmentation in Google Colab
train_dir = os.path.join(DATA_DIR, "train/")
augmented_train_dir = os.path.join(DATA_DIR, 'augmented_train/')

augment_dataset(train_dir, augmented_train_dir)

print("Augmentation complete. Augmented images saved to:", augmented_train_dir)
# Out:
# Augmentation complete. Augmented images saved to: /content/hw1_data/Dog_Emotion/augmented_train/

# %%
""" Data Preparation with Transformations """

transform_train = transforms.Compose([
    transforms.Resize((128, 128)),  # Ensure all images are resized to 128x128
    transforms.RandomResizedCrop((128,128), scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

transform_valtest = transforms.Compose([
    transforms.Resize((128, 128)),  # Ensure all images are resized to 128x128
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load datasets
train_dataset = dsets.ImageFolder(root=augmented_train_dir, transform=transform_train)
val_dataset = dsets.ImageFolder(root=os.path.join(DATA_DIR, 'val/'), transform=transform_valtest)
test_dataset = dsets.ImageFolder(root=os.path.join(DATA_DIR, 'test/'), transform=transform_valtest)

# Data loaders
batch_size = 100
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# %%
print(f"Number of training images: {len(train_dataset)}")
print(f"Number of validation images: {len(val_dataset)}")
print(f"Number of test images: {len(test_dataset)}")
# Out:
# Number of training images: 28000
# Number of validation images: 400
# Number of test images: 800

# %%
import torch
import torch.nn as nn

class OptimizedCNN(nn.Module):
    def __init__(self, num_classes=4):
        super(OptimizedCNN, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, padding=1),  # Reduced filters
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)                  # Output: (16, 64, 64)
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(16, 32, kernel_size=3, padding=1),  # Reduced filters
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)                  # Output: (32, 32, 32)
        )
        self.layer3 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1),  # Reduced filters
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)                  # Output: (64, 16, 16)
        )
        self.layer4 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, padding=1),  # Reduced filters
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)                  # Output: (64, 8, 8)
        )
        self.layer5 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1), # Final convolution layer
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d(1)                      # Global average pooling
        )

        # Fully connected layer
        self.fc = nn.Sequential(
            nn.Flatten(),                                 # Flatten the feature map
            nn.Linear(128, 64),                          # Input adjusted to Layer5 output
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(64, num_classes)                   # Output layer for 4 classes
        )

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = self.fc(out)
        return out

# %%
""" Training Function """
def train_and_validate(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    train_loss_history = []
    train_acc_history = []
    val_loss_history = []
    val_acc_history = []

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Track metrics
            running_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            correct_train += predicted.eq(labels).sum().item()
            total_train += labels.size(0)

        train_epoch_loss = running_loss / total_train
        train_epoch_acc = 100.0 * correct_train / total_train
        train_loss_history.append(train_epoch_loss)
        train_acc_history.append(train_epoch_acc)

        # Validation phase
        model.eval()
        running_val_loss = 0.0
        correct_val = 0
        total_val = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)

                running_val_loss += loss.item() * images.size(0)
                _, predicted = outputs.max(1)
                correct_val += predicted.eq(labels).sum().item()
                total_val += labels.size(0)

        val_epoch_loss = running_val_loss / total_val
        val_epoch_acc = 100.0 * correct_val / total_val
        val_loss_history.append(val_epoch_loss)
        val_acc_history.append(val_epoch_acc)

        # Print epoch results
        print(f"Epoch [{epoch+1}/{num_epochs}] "
              f"Train Loss: {train_epoch_loss:.4f}, Train Acc: {train_epoch_acc:.2f}% | "
              f"Val Loss: {val_epoch_loss:.4f}, Val Acc: {val_epoch_acc:.2f}%")

    return {
        'train_loss': train_loss_history,
        'train_acc': train_acc_history,
        'val_loss': val_loss_history,
        'val_acc': val_acc_history
    }

# %%
""" Train the Model """
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = OptimizedCNN().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()
history = train_and_validate(model, train_loader, val_loader, criterion, optimizer, num_epochs=25)
# Out:
# Epoch [1/25] Train Loss: 1.3192, Train Acc: 35.33% | Val Loss: 1.2939, Val Acc: 39.00%
# Epoch [2/25] Train Loss: 1.1380, Train Acc: 50.24% | Val Loss: 1.1226, Val Acc: 47.75%
# Epoch [3/25] Train Loss: 0.9886, Train Acc: 58.50% | Val Loss: 1.0300, Val Acc: 58.00%
# Epoch [4/25] Train Loss: 0.8875, Train Acc: 63.51% | Val Loss: 1.0636, Val Acc: 53.75%
# Epoch [5/25] Train Loss: 0.7943, Train Acc: 67.76% | Val Loss: 0.9547, Val Acc: 65.50%
# Epoch [6/25] Train Loss: 0.7316, Train Acc: 70.69% | Val Loss: 0.8460, Val Acc: 66.75%
# Epoch [7/25] Train Loss: 0.6621, Train Acc: 73.88% | Val Loss: 0.8399, Val Acc: 66.75%
# Epoch [8/25] Train Loss: 0.6036, Train Acc: 76.72% | Val Loss: 0.8175, Val Acc: 68.50%
# Epoch [9/25] Train Loss: 0.5492, Train Acc: 79.16% | Val Loss: 0.8996, Val Acc: 67.25%
# Epoch [10/25] Train Loss: 0.5014, Train Acc: 81.06% | Val Loss: 0.9760, Val Acc: 68.00%
# Epoch [11/25] Train Loss: 0.4606, Train Acc: 82.54% | Val Loss: 2.0225, Val Acc: 53.25%
# Epoch [12/25] Train Loss: 0.4329, Train Acc: 84.01% | Val Loss: 0.9279, Val Acc: 68.25%
# Epoch [13/25] Train Loss: 0.3951, Train Acc: 85.62% | Val Loss: 0.9139, Val Acc: 68.50%
# Epoch [14/25] Train Loss: 0.3641, Train Acc: 86.69% | Val Loss: 0.8684, Val Acc: 70.75%
# Epoch [15/25] Train Loss: 0.3449, Train Acc: 87.60% | Val Loss: 0.9582, Val Acc: 71.50%
# Epoch [16/25] Train Loss: 0.3175, Train Acc: 88.60% | Val Loss: 0.7990, Val Acc: 75.50%
# Epoch [17/25] Train Loss: 0.2894, Train Acc: 89.58% | Val Loss: 0.9133, Val Acc: 72.50%
# Epoch [18/25] Train Loss: 0.2621, Train Acc: 90.85% | Val Loss: 0.9788, Val Acc: 73.00%
# Epoch [19/25] Train Loss: 0.2564, Train Acc: 90.95% | Val Loss: 1.1744, Val Acc: 69.75%
# Epoch [20/25] Train Loss: 0.2414, Train Acc: 91.54% | Val Loss: 1.1468, Val Acc: 70.75%
# Epoch [21/25] Train Loss: 0.2394, Train Acc: 91.69% | Val Loss: 1.1366, Val Acc: 74.75%
# Epoch [22/25] Train Loss: 0.2271, Train Acc: 92.30% | Val Loss: 0.9166, Val Acc: 72.50%
# Epoch [23/25] Train Loss: 0.2111, Train Acc: 92.60% | Val Loss: 0.9407, Val Acc: 73.75%
# Epoch [24/25] Train Loss: 0.2012, Train Acc: 92.99% | Val Loss: 0.9009, Val Acc: 75.25%
# Epoch [25/25] Train Loss: 0.1887, Train Acc: 93.45% | Val Loss: 1.2058, Val Acc: 71.75%

# %%
torch.save(model.state_dict(), "HW1_Q3_319044434_314779166.pkl")

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 6))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history['train_loss'], label='train loss')
plt.plot(history['val_loss'], label='val loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history['train_acc'], label='train acc')
plt.plot(history['val_acc'], label='val acc')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')

plt.tight_layout()
plt.show()

# %%
model = OptimizedCNN().to(device)
model.load_state_dict(torch.load("HW1_Q3_319044434_314779166.pkl"))
# Out:
# C:\Users\amits\AppData\Local\Temp\ipykernel_14068\3076763798.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("HW1_Q3_319044434_314779166.pkl", map_location=torch.device('cpu')))
# <All keys matched successfully>

# %%
# evaluate the test set and print the value
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_accuracy = 100 * correct / total
print(f"Test Accuracy: {test_accuracy:.2f}%")
# Out:
# Test Accuracy: 71.75%

# %% [markdown]
# ## The proccess
#
# Initially, we analyzed the dataset distribution and observed that it was uniform, with 700 images per label. After multiple failed attempts, we concluded that the model was overfitting, primarily because the dataset was too small. To address this, we decided to apply extensive augmentations to the training set, increasing its size from 2,800 to 28,000 images, each original picture is being duplicated and trasformed diffrently(blur,mirror, direction etc).
#
# Throughout the experimentation process, we carefully analyzed the output after each training attempt. We tried tweaking hyperparameters such as the batch size, learning rate, and the number of epochs, but these adjustments alone did not yield significant improvements. The breakthrough came when we added a fifth layer to our CNN model, increasing its capacity to learn complex features.
#
# After further optimization, we observed that the dataset consistently converged to an optimum around 15 epochs, striking a balance between underfitting and overfitting. This approach ultimately helped us improve the model's generalization and performance.

# %% [markdown]
# ## II. Analyzing a Pre-trained CNN (Filters) (10pt)

# %% [markdown]
# In this part, you are going to analyze a (large) pre-trained model. Pre-trained models are quite popular these days, as big companies can train really large models on large datasets (something that personal users can't do as they lack the sufficient hardware). These pre-trained models can be used to fine-tune on other/small datasets or used as components in other tasks (like using a pre-trained classifier for object detection).
#
# All pre-trained models expect input images normalized in the same way, i.e. mini-batches of 3-channel RGB images of shape (3 x H x W), where H and W are expected to be at least 224. The images have to be loaded in to a range of [0, 1] and then normalized using mean = [0.485, 0.456, 0.406] and std = [0.229, 0.224, 0.225].
#
# You can use the following transform to normalize:
#
# <code>normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])</code>
# <a href="https://pytorch.org/vision/stable/models.html">Read more here</a>
#
#
# 1. Load a pre-trained VGG16 with PyTorch using torchvision.models.vgg16(pretrained=True, progress=True, **kwargs) (<a href="https://pytorch.org/vision/stable/models.html#classification">read more here</a>). Don't forget to use the model in evaluation mode (<code>model.eval()</code>).
#
# 2. Load the images in the <code>hw1_data/birds</code> folder and display them.
#
# 3. Pre-process the images to fit VGG16's architecture. What steps did you take?
#
# 4. Feed the images (forward pass) to the model. What are the outputs?
#
# 5. Choose an image of a dog in the <code>hw1_data/dogs</code> folder, display it and feed it to network. What are the outputs?
#
# 6. For the first 3 filters in the first layer of VGG16, plot their response (their output) for the image from section 5. Explain what do you see.

# %%
import torch
import torchvision
from torchvision import transforms
from PIL import Image
import os
import matplotlib.pyplot as plt
import json

# Load a pretrained VGG16 model
model_2 = torchvision.models.vgg16(pretrained=True, progress=True)

# Set the model to evaluation mode
model_2.eval()

# Print model structure
print(model_2)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:02<00:00, 218MB/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
bird_images_dir = os.path.join(RESOURCES_DIR, 'birds/')
bird_images = [img for img in os.listdir(bird_images_dir)]
jASON_DIR = os.path.join(RESOURCES_DIR, 'imagenet_class_index.json')

def display_bird_image(image):
    # Display the bird image
    img_path = os.path.join(bird_images_dir, image)
    img = Image.open(img_path)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

for image in bird_images:
    display_bird_image(image)

# Define the transformation
preprocess = transforms.Compose([
    transforms.Resize(256),  # Resize to 256x256 to maintain aspect ratio
    transforms.CenterCrop(224),  # Crop to 224x224
    transforms.ToTensor(),  # Convert the image to a PyTorch tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize
])
# Ensure the model is on the appropriate device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_2 = model_2.to(device)

bird_outputs = list()
for img_name in bird_images:
    img_path = os.path.join(bird_images_dir, img_name)
    image = Image.open(img_path)

    # Apply the pre-processing transformation
    input_tensor = preprocess(image)
    input_batch = input_tensor.unsqueeze(0).to(device)  # Add batch dimension

    # Feed the image to the model
    with torch.no_grad():
        output = model_2(input_batch)

    bird_outputs.append(output)

def print_output(title, output):
    print("~~ ", title, " ~~")
    print("Output shape: ", output.shape)  # Tensor of shape (1, 1000), containing scores for each of the 1000 ImageNet classes

    # Load the ImageNet class index JSON file
    with open(jASON_DIR, 'r') as f:
        class_idx = json.load(f)

    # Get the predicted class index from the output tensor
    _, predicted_idx = torch.max(output, 1)
    predicted_idx = predicted_idx.item()

    # Find the class label for the predicted index
    class_label = class_idx[str(predicted_idx)][1]
    print(f"Predicted class: {class_label}")

print_output("First output:", bird_outputs[0])
print_output("Second output:", bird_outputs[1])
# Out:
# ~~  First output:  ~~
# Output shape:  torch.Size([1, 1000])
# Predicted class: lorikeet
# ~~  Second output:  ~~
# Output shape:  torch.Size([1, 1000])
# Predicted class: hummingbird

# %% [markdown]
# We took the following steps when pre-processing the bird data:
# - Resizing the images to 256x256
# - The VGG expects the shape 3x224x224, so we cropped the images.
# - Normalized the images as required.
#
# The output is a tensor of shape (1, 1000), containing scores for each of the 1000 ImageNet classes.

# %%
# Load and preprocess the dog image
dog_images_dir = os.path.join(RESOURCES_DIR, 'dogs/')
dog_image_path = os.path.join(dog_images_dir, random.choice(os.listdir(dog_images_dir)))
dog_img = Image.open(dog_image_path)

# Display the dog image
plt.imshow(dog_img)
plt.axis('off')
plt.show()

# Preprocess the dog image
dog_input_tensor = preprocess(dog_img)
dog_input_batch = dog_input_tensor.unsqueeze(0).to(device)  # Move input tensor to the device

# Feed the dog image to the model
with torch.no_grad():
    dog_output = model(dog_input_batch)

print_output("Dog image output:", dog_output)
# Out:
# ~~  Dog image output:  ~~
# Output shape:  torch.Size([1, 4])
# Predicted class: tiger_shark

# %% [markdown]
# The output is a tensor of shape (1, 1000), containing scores for each of the 1000 ImageNet classes.

# %%
# Get the first convolutional layer from the model
first_conv_layer = model_2.features[0]

# Extract the first 3 filters (weights) from the first convolutional layer
filters = first_conv_layer.weight.data.cpu().numpy()

fig, axes = plt.subplots(1, 3, figsize=(12, 4))
for i in range(3):
    axes[i].imshow(filters[i, 0, :, :], cmap='gray')  # Display the filter as a 2D image
    axes[i].axis('off')
plt.show()

# Feeding the image to the first layer
first_conv_output = first_conv_layer(dog_input_batch)

# Plot the output response for the first 3 filters
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
for i in range(3):
    axes[i].imshow(first_conv_output[0, i].cpu().detach().numpy(), cmap='gray')  # Display the response for each filter
    axes[i].axis('off')
plt.show()

# %% [markdown]
# The output has shape (1, 64, 224, 224), while 64 is the number of output channels.
# Looking at the first feature maps, we see they captured simple patterns and textures. Also, we note that more advance the filter is, it recognizes complex patterns better. This plot visualizes how each filter detects other aspects of the image.
